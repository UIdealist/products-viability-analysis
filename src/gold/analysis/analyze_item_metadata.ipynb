# %% [markdown]
# # Examinación de información disponible referente a reseñas de productos
# Se tomará el repositorio de datos público de reseñas de productos de Amazon Reviews. Se trata de un conjunto de información recopilada en el 2020 referente a productos de diversas categorías. Actualmente se plantea el estudio de únicamente los productos pertenecientes al entorno tecnológico.
#
# Específicamente, se eligieron las siguientes categorías:
# - Accesorios y Celulares
# - Electrónica
# - Software
# - Videojuegos

# %% [markdown]
# ## Importación de librerias necesarias

# %%
import pyspark.sql.functions as F
from pyspark.sql import SQLContext, SparkSession, types as T, DataFrame
import requests
from pyspark.sql.functions import pandas_udf
from pyspark.sql.types import BinaryType
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType

from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

import tensorflow as tf
import numpy as np

from matplotlib.ticker import FuncFormatter

import tensorflow_hub as hub

import os
import dotenv
import re
import html

from delta import configure_spark_with_delta_pip

from pyspark.ml.functions import predict_batch_udf

# %%
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-17-openjdk-amd64"
print(os.popen("java -version 2>&1").read())
# Out:
# openjdk version "17.0.15" 2025-04-15
# OpenJDK Runtime Environment (build 17.0.15+6-Ubuntu-0ubuntu124.04)
# OpenJDK 64-Bit Server VM (build 17.0.15+6-Ubuntu-0ubuntu124.04, mixed mode, sharing)

# %%
REGENERATE_INTERMEDIATE = False

# %%
metastore_schema_path = "/mnt/c/Users/User/Documents/Maestría/Amazon Reviews Code/data"

# %%
builder = (
    SparkSession.builder \
        .appName("LocalUnityCatalog") \
        .config("spark.jars.packages", "io.delta:delta-spark_2.12:3.2.1,mysql:mysql-connector-java:8.0.33") \
        .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
        .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
        .config("spark.sql.warehouse.dir", f"{metastore_schema_path}/.warehouse") \
        .config("javax.jdo.option.ConnectionURL", f"jdbc:derby:{metastore_schema_path}/metastore_db;create=true") \
        .master("local[2]") \
        .enableHiveSupport()
)

spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
spark.sparkContext.setLogLevel("ERROR")

# %%
spark.sql("SHOW TABLES;").show(20)
# Out:
# +---------+---------+-----------+
# |namespace|tableName|isTemporary|
# +---------+---------+-----------+
# +---------+---------+-----------+

# %%
spark.table('spark_catalog.product_reviews_schema.meta_items')
# Out:
# DataFrame[title: string, main_category: string, features: array<string>, description: array<string>, average_rating: float, rating_number: int, price: double, store: string, parent_asin: string, categories: array<string>, details: string, images: array<string>]

# %% [markdown]
# ## Visualización de atributos del conjunto de datos

# %%
unified_reviews_clean = spark.table('spark_catalog.product_reviews_schema.reviews_clean')

# %%
def plot_histogram( df, column, num_bins, title, categorical = False ):

    plt.figure(figsize=(10, 6))

    if not categorical:
        min_val, max_val = df.agg(F.min(column), F.max(column)).first()
        bin_width = (max_val - min_val) / num_bins

        binned_df = df.withColumn("bin", ((F.col(column) - min_val) / bin_width).cast("int"))
        histogram_df = binned_df.groupBy("bin").count().orderBy("bin")
        pdf = histogram_df.toPandas()

        pdf["bin_center"] = min_val + (pdf["bin"] + 0.5) * bin_width

        plt.figure(figsize=(10, 6))
        plt.bar(pdf["bin_center"], pdf["count"], width=bin_width * 0.9, color='skyblue', edgecolor='black')
        plt.xlabel("Valor")
        plt.ylabel("Cantidad")
        plt.title(title)

        formatter = FuncFormatter(lambda x, pos: f'{int(x):,}')
        plt.gca().xaxis.set_major_formatter(formatter)
        plt.gca().yaxis.set_major_formatter(formatter)

    else:
        agg_df = df.groupBy(column).count().orderBy("count", ascending=False).limit(20)
        pdf = agg_df.toPandas()
        categories = pdf[column]
        counts = pdf['count']
        bars = plt.bar(categories, counts, color='skyblue')

        for bar, count in zip(bars, counts):
            height = bar.get_height()
            plt.text(bar.get_x() + bar.get_width() / 2, height,
                     f'{count:,}',
                     ha='center', va='bottom', fontsize=9)

        plt.xlabel("Valor")
        plt.ylabel("Cantidad")
        plt.title(title)
    plt.show()

# %%
plot_histogram(
    unified_reviews_clean, 'rating', 20,
    'Distribución de calificaciones de usuario a nivel global',
    True
)

# %% [markdown]
# ## Representación semántica de referencias de productos
# La mayor parte del conjunto de datos original se conforma de las reseñas de usuarios de los productos publicados en Amazon. Cada una de estas referencias aporta valor describiendo la satisfacción de los usuarios con respecto al producto usado. En este sentido, vale la pena examinar algunas caracterizaciones preliminares a través de modelos pre-entrenados que permitan representar dichos textos en un formato interpretable por modleos posteriores.

# %%
# https://www.tensorflow.org/hub/tutorials/semantic_similarity_with_tf_hub_universal_encoder?hl=es-419
MODULE_URL = "https://tfhub.dev/google/universal-sentence-encoder/4"
model = hub.load( MODULE_URL )
# Out:
# 2025-06-07 15:37:15.011584: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %% [markdown]
# Se usará el modelo Universal Sentence Encoder para generar la representación numérica de las descripciones proveídas por usuarios

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
unified_reviews_with_phrases = (
    unified_reviews_clean
        .withColumn(
            'sentence',
            F.explode( F.split(F.col("text"), "\\.") )
        )
)

# %%
pandas_sample = (
    unified_reviews_with_phrases
        .filter(
            F.col('sentence').isNotNull() &
            (F.length( F.col('sentence') ) > 0 )
        )
        .limit(100000)
        .toPandas()
)

# %%
sentences = pandas_sample['sentence'].to_numpy()

# %%
embeddings = model( sentences )
embeddings.shape
# Out:
# 2025-06-07 15:37:26.179890: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 816000000 exceeds 10% of free system memory.
# 2025-06-07 15:37:32.731601: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 816000000 exceeds 10% of free system memory.
# 2025-06-07 15:37:34.280046: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 3484482560 exceeds 10% of free system memory.
# TensorShape([100000, 512])

# %%
pca = PCA(n_components=2)
embeddings_2d = pca.fit_transform(embeddings.numpy())
f'Varianza explicada: {pca.explained_variance_ratio_.sum() * 100} %'
# Out:
# 'Varianza explicada: 9.489971160888672 %'

# %%
def sample_and_plot( ax, embedded_2d, words ):
  random_indexes = np.random.choice(embedded_2d.shape[0], size=20, replace=False)
  sampled_labels = [words[i] for i in random_indexes]
  sampled_embedded_2d = embedded_2d[random_indexes]

  ax.scatter(sampled_embedded_2d[:, 0], sampled_embedded_2d[:, 1], color='skyblue')

  for i, _ in enumerate(sampled_labels):
      index = random_indexes[ i ]
      ax.annotate(f'{index}', (sampled_embedded_2d[i, 0], sampled_embedded_2d[i, 1]))

  ax.set_title('Representación de algunas opiniones codificadas mediante modelo pre-entrenado')
  ax.set_xlabel('Comp 1')
  ax.set_ylabel('Comp 2')

  return random_indexes

# %%
fig, axes = plt.subplots(2,2,figsize=(20, 20))
axes = axes.flatten()

indexes = []

for ax in axes:
    indexes.extend( sample_and_plot( ax, embeddings_2d, sentences ) )

plt.grid(True, linestyle='--', alpha=0.5)
fig.show()
# Out:
# /tmp/ipykernel_177092/1562355271.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
indexes = list(set(indexes))

# %%
for id in sorted(indexes):
    print(f'ID: {id} Descripcion: {sentences[id]}')
# Out:
# ID: 1110 Descripcion: Dañado y roto 😠
# ID: 3822 Descripcion:  If you want an even faster rate, get one of the shorter IXCC Element Series cables
# ID: 5283 Descripcion: Kick-stand was very flimsy and weak
# ID: 5859 Descripcion:  Returned and given a refund
# ID: 6164 Descripcion:  Won't be a waste of time
# ID: 6942 Descripcion: After 6 mos the product failed
# ID: 7592 Descripcion:  I received numerous compliments! It is the best price for the great quality it endures
# ID: 8293 Descripcion: I am currently using the magnet metal strap and it does it job so far
# ID: 9042 Descripcion: Poorly described
# ID: 15685 Descripcion:  The mirror is wide enough to view the back seat
# ID: 16343 Descripcion: So far so good
# ID: 19728 Descripcion: Not very protective
# ID: 20096 Descripcion: <br />- The sides are quite grippy, but not in that clingy Apple silicone way where it pulls your pockets inside out and wears out after a few months
# ID: 21081 Descripcion:  I now have a broken case with ripped plastic and have wasted my money
# ID: 21396 Descripcion:   You can see in the pictures that it's impossible to seal the screen since it goes over cracks between the monitor and the case
# ID: 24318 Descripcion: Exactly what I expected!!!
# ID: 25806 Descripcion: 55 out of pocket for nothing!?!
# ID: 27339 Descripcion:  For what it's worth, changing the nib every month when you have 16 in total doesn't seem like a bad deal when it helps dampen the tapping noise and "grips" onto the screen better
# ID: 27560 Descripcion:  You cant even reach the power button without using your fingernail
# ID: 27710 Descripcion:  The only issue, is that the phone can slip out very easily out of the holster
# ID: 30140 Descripcion: <br /><br />I did have a warranty issue and GPS City did a fantastic and speedy job of taking care of it to my complete satisfaction
# ID: 30856 Descripcion:  Make sure go to your setting and make your screen never go idle and use your side bottoms to take the pictures and videos
# ID: 31706 Descripcion: Perfect as always!
# ID: 31805 Descripcion: It’s a simple case
# ID: 31848 Descripcion: The tripod has good quality clips that allow you to adjust on each level
# ID: 32380 Descripcion: Great option for my elderly parent
# ID: 35051 Descripcion: <br /><br />The other negatives about this case are that the mute switch is hard to access without growing my fingernails, and the camera lenses are completely unprotected, so I now have to clean them occasionally
# ID: 35279 Descripcion:   Provides great protection for my Galaxy s7
# ID: 35362 Descripcion:  Legal way to touch phone while driving
# ID: 35791 Descripcion: Great case
# ID: 36345 Descripcion:  Package was well sealed
# ID: 36426 Descripcion: I’m glad I purchased this! Great screen protectors and easy to apply! When you open it there are numerous items but each step is labeled
# ID: 40042 Descripcion:  That is why I reordered the same one but it didn't smell like this one
# ID: 40056 Descripcion:  I'm not buying this brand again!!!
# ID: 40150 Descripcion: This is my third one now because I like the different colors so far I won't buy any other ones because these hold up so well definitely worth the buy
# ID: 40269 Descripcion: Sides of the cover comes loose
# ID: 43227 Descripcion: DONT BUY! IT DOESNT FIT IPHONE PROPERLY
# ID: 45227 Descripcion:  It can not even be seen, it just blends in seamlessly and when I run out of the pack of 6 I purchased I will definitely be buying more from this brand
# ID: 45904 Descripcion:  Can easily pop open sometimes if you have it attached to your hip but that’s more of the actual case
# ID: 47306 Descripcion: El protector de pantalla llevo roto, todo lo demás muy bien
# ID: 47653 Descripcion:  With this one I’ve had the opposite problem - the swivel part works fine but the hinge is broken
# ID: 48186 Descripcion: <br />I have have purchased 3 in shield screen protectors for 3 phones
# ID: 50117 Descripcion:  I contacted the company to get replacement dividers and they are not available
# ID: 52781 Descripcion:  I don’t have any complaints
# ID: 52949 Descripcion: Parked my car at the airport in 80F temperature and after I returned in a weeks time the unit was not working
# ID: 55750 Descripcion: Really looks cheap, magnet cover fell of at the first try
# ID: 55869 Descripcion:  Others, I have to attempt to reset it- but I can't touch the power off button because it's still going crazy
# ID: 56206 Descripcion:  I have an iPhone 6 plus and there is no indication on the package for the 6 plus
# ID: 57879 Descripcion:  DONE—No Headache Needed
# ID: 58005 Descripcion:  The other one in the pack was fine and works well
# ID: 58148 Descripcion:  Super easy to install and very durable
# ID: 60573 Descripcion:  It's easy to install, and the longer arm easily grips the fan vent
# ID: 61483 Descripcion: Great case for the price!  The only think I don't like is that it is hard to put in my jeans pocket because of the soft plastic corners
# ID: 63925 Descripcion:  This one will lasts me months before I chose to replace
# ID: 66229 Descripcion:  I just use it for calling, but its worth every dollar I paid for it
# ID: 66280 Descripcion:  Donated to thrift shop
# ID: 67445 Descripcion: I bought this as part of the solution to connect my firestick (2nd gen) to an ethernet cable (which also required a separate USB to ethernet adapter) and it worked perfectly right out of the box
# ID: 68343 Descripcion: Moto g power (2021)
# ID: 68963 Descripcion:  It covers all the edges and key points perfectly
# ID: 69267 Descripcion: This ring light ensemble is top notch for its price range
# ID: 70140 Descripcion:  I was able to figure out the method needed to assemble it only after looking at the promo pics
# ID: 72581 Descripcion:   It has a very nice feel in your hand
# ID: 74563 Descripcion: They work as indicated, good cables for a great price
# ID: 76745 Descripcion:   It arrived quickly and was beyond my expectations
# ID: 78229 Descripcion:   I bought it for my daughter for Christmas but it got her today
# ID: 79702 Descripcion:  I had to change the original pad
# ID: 81621 Descripcion: This was an amazing battery it charged so many devices and the solar power aspect was amazing
# ID: 81887 Descripcion:  Dirty and broken
# ID: 82784 Descripcion: <br /><br />The navigation edition comes with a CR-103 telephone cradle, in four parts, with two screws, and no instructions on how to put the pieces together
# ID: 82924 Descripcion:  In actuality, these cables are not very durable at all
# ID: 84911 Descripcion:  Sticks and stays on well easily cleaned
# ID: 85509 Descripcion:  Although I haven't tested their theory, I have seen plenty of review videos of the screen protector actually protecting the screen from a hammer blow, which is incredible
# ID: 89033 Descripcion: It does not cover the edges so you gaps all around the edges
# ID: 90715 Descripcion: Very sturdy, fits my Samsung Galaxy S9+ with the case on
# ID: 93129 Descripcion:   Have to take my phone out of case to use phone basic functions
# ID: 93321 Descripcion:  I purchased it as a cheap alternative to the s-View cases and it doesn't work with s-View at all
# ID: 94231 Descripcion: These screen protectors are not that good
# ID: 95410 Descripcion:  After this appearance in the Hulk, he next appeared in the third season of Spider-Man And His Amazing Friends ("Spidey Meets The Girl From Tomorrow"), again voiced by an (uncredited) Michael Bell
# ID: 96968 Descripcion: Broke within a mooth
# ID: 97023 Descripcion:  My husband & I, both have the problem
